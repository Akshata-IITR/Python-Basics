# %%
print("Hello my coding journey begins here!!")
# Out:
# Hello my coding journey begins here!!

# %%
name = input("Enter your name:")
Occupation= input ("Enter your occupation:")
if(Occupation== "Student"):
    I = input ("Enter Institute name:")
else: 
 I =input("Enter post:")
print(" Hello everyone my name is "+ name +" I am a " + Occupation +" at "+ I+"." )
Department= input("Enter department name:")
year = input("Enter year of study")

print("I am in the department of "+ Department +" in the "+ year +  " year of MTech. I will complete my MTech in june 2026.")
Interest=input("Enter your interest:")
print("My interest is mainly in",Interest )
# Out:
#  Hello everyone my name is A I am a Student at IITR.
# I am in the department of AMSC in the 2nd year of MTech. I will complete my MTech in june 2026.
# My interest is mainly in GNN
